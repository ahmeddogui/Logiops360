# %% [markdown]
# ## Exploitation de données

# %% [markdown]
# #### Monthly_Modal_Time_series.csv

# %%
import pandas as pd

file_path = r"C:\Users\ahmed\OneDrive\Bureau\Projet LogiOps360\logiOps360\logiOps360\Transport\Data\Monthly_Modal_Time_Series_20250611.csv"
df_modal = pd.read_csv(file_path)
df_modal.head()
# Out:
#    NTD ID                     Agency  \
# 0   20008  MTA New York City Transit
# 1   20008  MTA New York City Transit
# 2   20008  MTA New York City Transit
# 3   20008  MTA New York City Transit
# 4   20008  MTA New York City Transit
#
#                                 Organization Type Mode Type of Service  \
# 0  Unit of a Transit Agency, Reporting Separately   HR              DO
# 1  Unit of a Transit Agency, Reporting Separately   HR              DO
# 2  Unit of a Transit Agency, Reporting Separately   HR              DO
# 3  Unit of a Transit Agency, Reporting Separately   HR              DO
# 4  Unit of a Transit Agency, Reporting Separately   HR              DO
#
#    Rail (True/False)  Primary UZA UACE Code  \
# 0               True                63217.0
# 1               True                63217.0
# 2               True                63217.0
# 3               True                63217.0
# 4               True                63217.0
#
# ...

# %%
null_percent = df_modal.isnull().mean() * 100
null_percent
# Out:
# NTD ID                                                   0.000000
# Agency                                                   0.000000
# Organization Type                                        5.850481
# Mode                                                     0.000000
# Type of Service                                          0.000000
#                                                           ...
# Major Non-Physical Assaults on Operators                87.345212
# Major Physical Assaults on Other Transit Workers        87.345212
# Major Non-Physical Assaults on Other Transit Workers    87.345212
# Total Assaults on Transit Workers                       87.322708
# MoYr                                                     0.000000
# Length: 75, dtype: float64

# %%
df_modal.describe()
# Out:
#               NTD ID  Primary UZA UACE Code  Primary UZA Sq Miles  \
# count  173302.000000          168506.000000         168506.000000
# mean    48207.838092           50651.905968            650.528859
# std     27783.991288           28467.925360            805.078650
# min         1.000000              42.000000              0.000000
# 25%     30034.000000           23527.000000             91.850000
# 50%     50008.000000           52390.000000            300.420000
# 75%     70008.000000           77068.000000            906.640000
# max     99425.000000           99999.000000           3248.120000
#
#        Primary UZA Population  Service Area Sq Miles  Service Area Population  \
# count            1.685060e+05          163233.000000             1.632330e+05
# mean             2.689918e+06             674.729712             9.662606e+05
# std              4.503735e+06            1954.114286             1.728051e+06
# ...

# %%
distinct_counts = df_modal.nunique()
print(distinct_counts)

for col in df_modal.columns:
    print(f"\nColumn: {col}")
    print(df_modal[col].unique())
# Out:
# NTD ID                                                  631
# Agency                                                  629
# Organization Type                                        11
# Mode                                                     16
# Type of Service                                           4
#                                                        ...
# Major Non-Physical Assaults on Operators                  3
# Major Physical Assaults on Other Transit Workers         18
# Major Non-Physical Assaults on Other Transit Workers      2
# Total Assaults on Transit Workers                       101
# MoYr                                                    136
# Length: 75, dtype: int64
#
# Column: NTD ID
# [20008 20217 30102 90044 90024 90157 90039 40037 40029 40179 60041 20193
#  20075 30103 30058 30051 10117 10005 50141    29    40    35 90003 90134
#  90009 50154 40200 90031 90086 70006     8 90224 30078 50143 40222 10045
# ...

# %%
num_lines = len(df_modal)
print(f"Number of lines: {num_lines}"²²²²²²²²²²²1)
# Out:
# Number of lines: 173302
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
file_path = r"C:\Users\ahmed\OneDrive\Bureau\Projet LogiOps360\logiOps360\logiOps360\Transport\Data\smart_logistics_dataset.csv"
df_smart = pd.read_csv(file_path)
df_smart.head()
# Out:
#              Timestamp  Asset_ID  Latitude  Longitude  Inventory_Level  \
# 0  2024-03-20 00:11:14   Truck_7  -65.7383    11.2497              390
# 1  2024-10-30 07:53:51   Truck_6   22.2748  -131.7086              491
# 2  2024-07-29 18:42:48  Truck_10   54.9232    79.5455              190
# 3  2024-10-28 00:50:54   Truck_9   42.3900    -1.4788              330
# 4  2024-09-27 15:52:58   Truck_7  -65.8477    47.9468              480
#
#   Shipment_Status  Temperature  Humidity Traffic_Status  Waiting_Time  \
# 0         Delayed         27.0      67.8         Detour            38
# 1      In Transit         22.5      54.3          Heavy            16
# 2      In Transit         25.2      62.2         Detour            34
# 3       Delivered         25.4      52.3          Heavy            37
# 4         Delayed         20.5      57.2          Clear            56
#
#    User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# ...

# %%
df_smart.describe()
# Out:
#           Latitude    Longitude  Inventory_Level  Temperature     Humidity  \
# count  1000.000000  1000.000000      1000.000000  1000.000000  1000.000000
# mean     -1.360093     0.837049       297.915000    23.893900    65.042200
# std      51.997183   104.843618       113.554773     3.322178     8.753765
# min     -89.791500  -179.820200       100.000000    18.000000    50.000000
# 25%     -46.167975   -88.448075       201.000000    21.200000    57.200000
# 50%      -4.503150     0.678300       299.000000    23.800000    65.200000
# 75%      44.502800    88.156450       399.000000    26.600000    72.400000
# max      89.870100   179.923700       500.000000    30.000000    80.000000
#
#        Waiting_Time  User_Transaction_Amount  User_Purchase_Frequency  \
# count   1000.000000              1000.000000              1000.000000
# mean      35.062000               299.055000                 5.513000
# std       14.477768               117.787792                 2.935379
# ...

# %%
null_percent = df_smart.isnull().mean() * 100
null_percent
# Out:
# Timestamp                   0.0
# Asset_ID                    0.0
# Latitude                    0.0
# Longitude                   0.0
# Inventory_Level             0.0
# Shipment_Status             0.0
# Temperature                 0.0
# Humidity                    0.0
# Traffic_Status              0.0
# Waiting_Time                0.0
# User_Transaction_Amount     0.0
# User_Purchase_Frequency     0.0
# Logistics_Delay_Reason     26.3
# Asset_Utilization           0.0
# Demand_Forecast             0.0
# Logistics_Delay             0.0
# dtype: float64

# %%
file_path2 = r"C:\Users\ahmed\OneDrive\Bureau\Projet LogiOps360\logiOps360\logiOps360\Transport\Data\Supply chain logisitcs problem.xlsx"
df_supply = pd.read_excel(file_path2)
df_supply.head()
# Out:
#        Order ID Order Date Origin Port Carrier  TPT Service Level  \
# 0  1.447296e+09 2013-05-26      PORT09   V44_3    1           CRF
# 1  1.447158e+09 2013-05-26      PORT09   V44_3    1           CRF
# 2  1.447139e+09 2013-05-26      PORT09   V44_3    1           CRF
# 3  1.447364e+09 2013-05-26      PORT09   V44_3    1           CRF
# 4  1.447364e+09 2013-05-26      PORT09   V44_3    1           CRF
#
#    Ship ahead day count  Ship Late Day count   Customer  Product ID  \
# 0                     3                    0  V55555_53     1700106
# 1                     3                    0  V55555_53     1700106
# 2                     3                    0  V55555_53     1700106
# 3                     3                    0  V55555_53     1700106
# 4                     3                    0  V55555_53     1700106
#
#   Plant Code Destination Port  Unit quantity  Weight
# 0    PLANT16           PORT09            808   14.30
# ...

# %%
distinct_counts = df_supply.nunique()
print(distinct_counts)

for col in df_supply.columns:
    print(f"\nColumn: {col}")
    print(df_supply[col].unique())

df_supply.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 distinct_counts = df_supply.nunique()
#       2 print(distinct_counts)
#       4 for col in df_supply.columns:
#
# NameError: name 'df_supply' is not defined

# %%
distinct_counts = df_supply.nunique()
print(distinct_counts)

for col in df_supply.columns:
    print(f"\nColumn: {col}")
    print(df_supply[col].unique())

df_supply.describe()

# %%
null_percent = df_supply.isnull().mean() * 100
null_percent
# Out:
# Order ID                0.0
# Order Date              0.0
# Origin Port             0.0
# Carrier                 0.0
# TPT                     0.0
# Service Level           0.0
# Ship ahead day count    0.0
# Ship Late Day count     0.0
# Customer                0.0
# Product ID              0.0
# Plant Code              0.0
# Destination Port        0.0
# Unit quantity           0.0
# Weight                  0.0
# dtype: float64

# %%
file_path2 = r"C:\Users\ahmed\OneDrive\Bureau\Projet LogiOps360\logiOps360\logiOps360\Transport\Data\Transportation and Logistics Tracking Dataset..xlsx"
df_track = pd.read_excel(file_path2)
df_track
# Out:
#         GpsProvider           BookingID Market/Regular   \
# 0     CONSENT TRACK  MVCV0000927/082021          Market
# 1           VAMOSYS  VCV00014271/082021         Regular
# 2     CONSENT TRACK  VCV00014382/082021         Regular
# 3           VAMOSYS  VCV00014743/082021         Regular
# 4           VAMOSYS  VCV00014744/082021         Regular
# ...             ...                 ...             ...
# 6875          JTECH        WDSBKTP42751         Regular
# 6876          JTECH        WDSBKTP43203         Regular
# 6877          JTECH        WDSBKTP43021         Regular
# 6878          JTECH        WDSBKTP42685         Regular
# 6879          JTECH        WDSBKTP42858         Regular
#
#               BookingID_Date  vehicle_no  \
# 0    2020-08-17 14:59:01.000    KA590408
# 1    2020-08-27 16:22:22.827  TN30BC5917
# 2    2020-08-27 17:59:24.987  TN22AR2748
# 3    2020-08-28 00:48:24.503  TN28AQ0781
# 4    2020-08-28 01:23:19.243   TN68F1722
# ...

# %%
df_track.describe()
# Out:
#                       BookingID_Date                 Data_Ping_time  \
# count                           6880                           5927
# mean   2020-02-08 05:18:40.453054208  2020-04-06 04:54:24.370193920
# min              2019-03-18 12:19:22            2019-06-07 18:25:10
# 25%       2019-10-11 18:47:32.500000            2019-12-01 07:35:10
# 50%       2020-01-20 13:49:40.500000            2020-06-19 16:10:08
# 75%    2020-07-30 13:46:34.750000128            2020-08-10 15:52:45
# max              2020-12-03 13:10:21            2020-08-28 12:40:31
# std                              NaN                            NaN
#
#           Curr_lat     Curr_lon  TRANSPORTATION_DISTANCE_IN_KM  \
# count  5927.000000  5927.000000                    6168.000000
# mean     18.679995    78.759745                     553.856282
# min       8.166790    69.657698                       0.000000
# 25%      12.871868    76.891857                      40.000000
# ...

# %%
null_percent = df_track.isnull().mean() * 100
null_percent
# Out:
# GpsProvider                           13.851744
# BookingID                              0.000000
# Market/Regular                         0.000000
# BookingID_Date                         0.000000
# vehicle_no                             0.000000
# Origin_Location                        0.000000
# Destination_Location                   0.000000
# Org_lat_lon                            0.000000
# Des_lat_lon                            0.000000
# Data_Ping_time                        13.851744
# Planned_ETA                            0.000000
# Current_Location                      14.011628
# DestinationLocation                    0.000000
# actual_eta                             0.537791
# Curr_lat                              13.851744
# Curr_lon                              13.851744
# ontime                                62.965116
# delay                                 36.889535
# OriginLocation_Code                    0.043605
# DestinationLocation_Code               0.392442
# ...
